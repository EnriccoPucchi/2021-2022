# %% [markdown]
# <a href="https://colab.research.google.com/github/EnriccoPucchi/2021-2022/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### РОССИЙСКИЙ УНИВЕРСИТЕТ ДРУЖБЫ НАРОДОВ
#
# #### Факультет физико-математических и естественных наук
# #### Кафедра информационных технологий

# %% [markdown]
# ## ОТЧЕТ ПО ЛАБОРАТОРНОЙ РАБОТЕ № 1
#
#
# ### Дисциплина: Методы машинного обучения

# %% [markdown]
# ##### Студент:  Уваров Андрей Дмитриевич
# ##### Группа:   НКНбд-01-19

# %% [markdown]
# ## Москва 2022
# ***

# %% [markdown]
# ### Вариант №17

# %% [markdown]
# ##1. Загрузите из набора данных ‘diamonds’ следующие признаки: features/carat, features/table, features/z

# %%
# !pip install -q tfds-nightly
# Out:
#      |████████████████████████████████| 4.3 MB 17.4 MB/s
#      |████████████████████████████████| 86 kB 3.5 MB/s

# %%
import numpy as np
import pandas as pd
import tensorflow_datasets as tfds

# %%
data = tfds.load("diamonds", split = "train")
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# ...
# Generating train examples...:   0%|          | 0/53940 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/diamonds/1.0.0.incompleteRY3MCS/diamonds-train.tfrecord*...:   0%|          | …
# Dataset diamonds downloaded and prepared to ~/tensorflow_datasets/diamonds/1.0.0. Subsequent calls will reuse this data.

# %%
df = tfds.as_dataframe(data)[['features/carat', 'features/table', 'features/z']]
df.head()
# Out:
#    features/carat  features/table  features/z
# 0            1.26            60.0        4.23
# 1            0.80            54.0        3.71
# 2            0.56            54.0        3.27
# 3            1.51            58.0        4.64
# 4            0.33            54.0        2.76

# %%
desc_table = df.describe()
desc_table
# Out:
#        features/carat  features/table    features/z
# count    53940.000000    53940.000000  53940.000000
# mean         0.797950       57.457226      3.538748
# std          0.474018        2.234392      0.705719
# min          0.200000       43.000000      0.000000
# 25%          0.400000       56.000000      2.910000
# 50%          0.700000       57.000000      3.530000
# 75%          1.040000       59.000000      4.040000
# max          5.010000       95.000000     31.799999

# %% [markdown]
# ##2. Определите признак с минимальным квантилем уровня 0.8 и постройте диаграмму размаха значений признака.

# %%
df.quantile(0.8)
# Out:
# features/carat     1.13
# features/table    59.00
# features/z         4.13
# Name: 0.8, dtype: float64

# %% [markdown]
# У признака features/carat квантиль уровня 0,8 минимален

# %%
df['features/carat'].plot.box(title='Диаграмма размаха признака features/carat');

# %% [markdown]
# ##3. Для признака, имеющего минимальную медиану, постройте и визуализируйте эмпирическую функцию распределения.

# %%
df.median()
# Out:
# features/carat     0.70
# features/table    57.00
# features/z         3.53
# dtype: float32

# %% [markdown]
# Мендиана минимальна у features/carat

# %%
def ECDF(data, x):
    counter = 0
    for v in data:
        if v <= x:
            counter += 1
    return counter / len(data)

# %%
samples = df['features/carat']
npoints = 500
dx = (samples.max()-samples.min())/npoints

xlist = [samples.min()+dx*i for i in range(npoints)]
ylist = [ECDF(samples, x) for x in xlist]

# %%
df_ECDF = pd.DataFrame(ylist, columns=['features/carat'],index=xlist)
df_ECDF
# Out:
#          features/carat
# 0.20000        0.000222
# 0.20962        0.000222
# 0.21924        0.000389
# 0.22886        0.000482
# 0.23848        0.005914
# ...                 ...
# 4.96190        0.999981
# 4.97152        0.999981
# 4.98114        0.999981
# 4.99076        0.999981
# 5.00038        0.999981
#
# [500 rows x 1 columns]

# %%
df_ECDF.plot.line(title='График эмпирической функции распределения признака features/carat');

# %% [markdown]
# ##4. Вычислите матрицу ковариации признаков и для пары признаков с наиболее высокой ковариацией постройте диаграмму рассеяния.

# %%
df.cov()
# Out:
#                 features/carat  features/table  features/z
# features/carat        0.224687        0.192365    0.318917
# features/table        0.192365        4.992948    0.237996
# features/z            0.318917        0.237996    0.498011

# %% [markdown]
# Наиболее высокая ковариация у features/z и features/carat

# %%
df.plot.scatter('features/z','features/carat',title='Диаграмма рассеяния признаков features/z \
и features/carat');
